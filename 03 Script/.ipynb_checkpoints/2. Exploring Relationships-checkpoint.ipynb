# %% [markdown]
# # 01. Importing libraries and dataset

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
#Check the version of matplotlib
matplotlib.__version__
# Out:
# '3.8.4'

# %%
# This option ensures the charts I create are displayed in the notebook without the need to "call" them specifically.
# %matplotlib inline

# %%
# Define path
path = r'C:\Users\vicky\OneDrive\文件\careerfoundry\Data Analytics Immersion\Exercise 6\05-2024 Project'

# %%
# import data & only include the variables columns that make sense for exploratory visual analysis
vars_list = ['Age', 'Number of Dependents', 'Number of Referrals', 'Tenure in Months', 'Avg Monthly Long Distance Charges', 'Avg Monthly GB Download','Monthly Charge','Total Charges','Total Refunds','Total Extra Data Charges','Total Long Distance Charges','Total Revenue','Satisfaction Score','Churn Score','CLTV']

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Telco_cleaned.csv'), usecols = vars_list)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                7043 non-null   int64
#  1   Number of Dependents               7043 non-null   int64
#  2   Number of Referrals                7043 non-null   int64
#  3   Tenure in Months                   7043 non-null   int64
#  4   Avg Monthly Long Distance Charges  7043 non-null   float64
#  5   Avg Monthly GB Download            7043 non-null   int64
#  6   Monthly Charge                     7043 non-null   float64
#  7   Total Charges                      7043 non-null   float64
#  8   Total Refunds                      7043 non-null   float64
#  9   Total Extra Data Charges           7043 non-null   int64
#  10  Total Long Distance Charges        7043 non-null   float64
# ...

# %%
#rename columns
df.rename(columns = {'Number of Dependents' : 'Dependents'}, inplace = True)
df.rename(columns = {'Number of Referrals' : 'Referrals'}, inplace = True)
df.rename(columns = {'Tenure in Months' : 'Tenure_Months'}, inplace = True)
df.rename(columns = {'Avg Monthly Long Distance Charges' : 'avg_m_LD_Charge'}, inplace = True)
df.rename(columns = {'Avg Monthly GB Download' : 'avg_m_GB_download'}, inplace = True)
df.rename(columns = {'Monthly Charge' : 'Monthly_Charge'}, inplace = True)
df.rename(columns = {'Total Charges' : 'Total_Charges'}, inplace = True)
df.rename(columns = {'Total Refunds' : 'Total_Refunds'}, inplace = True)
df.rename(columns = {'Total Extra Data Charges' : 'Total_ED_Charges'}, inplace = True)
df.rename(columns = {'Total Long Distance Charges' : 'Total_LD_Charges'}, inplace = True)
df.rename(columns = {'Total Revenue' : 'Total_Revenue'}, inplace = True)
df.rename(columns = {'Satisfaction Score' : 'Satisfaction'}, inplace = True)
df.rename(columns = {'Churn Score' : 'Churn'}, inplace = True)

# %% [markdown]
# # 02. Exploring Relationships

# %% [markdown]
# ## Correlations:

# %%
# Create a correlation matrix using pandas
df.corr()
# Out:
#                         Age  Dependents  Referrals  Tenure_Months  \
# Age                1.000000   -0.119000  -0.025141       0.009927
# Dependents        -0.119000    1.000000   0.278003       0.108237
# Referrals         -0.025141    0.278003   1.000000       0.326975
# Tenure_Months      0.009927    0.108237   0.326975       1.000000
# avg_m_LD_Charge   -0.011749   -0.007324   0.006336       0.014596
# avg_m_GB_download -0.376595    0.129966   0.038575       0.049119
# Monthly_Charge     0.144685   -0.131837   0.028173       0.247582
# Total_Charges      0.059684    0.022535   0.250378       0.826074
# Total_Refunds      0.024168    0.014023   0.024756       0.059021
# Total_ED_Charges   0.025036   -0.014436   0.000350       0.082266
# Total_LD_Charges   0.003065    0.068966   0.216190       0.674149
# Total_Revenue      0.048265    0.038038   0.261853       0.853146
# Satisfaction      -0.085170    0.152873   0.188926       0.210557
# ...

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(df.corr())
plt.show()

# %%
# Save figure
plt.matshow(df.corr())
plt.savefig("out.png")

# %%
#current dir
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\vicky\\OneDrive\\文件\\careerfoundry\\Data Analytics Immersion\\Exercise 6\\05-2024 Project\\03 Script'

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(9, 9)) # figure size 
plt.matshow(df.corr(), fignum=f.number) # type of plot
plt.xticks(range(df.shape[1]), df.columns, fontsize=10, rotation=45) # x axis labels
plt.yticks(range(df.shape[1]), df.columns, fontsize=10) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=10) # add font size
plt.title('Correlation Matrix', fontsize=12) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
df.columns
# Out:
# Index(['Age', 'Dependents', 'Referrals', 'Tenure_Months', 'avg_m_LD_Charge',
#        'avg_m_GB_download', 'Monthly_Charge', 'Total_Charges', 'Total_Refunds',
#        'Total_ED_Charges', 'Total_LD_Charges', 'Total_Revenue', 'Satisfaction',
#        'Churn', 'CLTV'],
#       dtype='object')

# %%
# Create a subset excluding the "Date" and "No" columns

sub = df[['Age', 'Dependents', 'Referrals', 'Tenure_Months', 
       'avg_m_GB_download', 'Monthly_Charge', 'Total_LD_Charges', 'Total_Revenue', 'Satisfaction',
       'Churn', 'CLTV']]

# %%
sub
# Out:
#       Age  Dependents  Referrals  Tenure_Months  avg_m_GB_download  \
# 0      78           0          0              1                  8
# 1      74           1          1              8                 17
# 2      71           3          0             18                 52
# 3      78           1          1             25                 12
# 4      80           1          1             37                 14
# ...   ...         ...        ...            ...                ...
# 7038   30           0          0             72                  0
# 7039   38           2          1             24                 24
# 7040   30           2          4             72                 59
# 7041   32           2          1             11                 17
# 7042   44           0          0             66                 11
#
#       Monthly_Charge  Total_LD_Charges  Total_Revenue  Satisfaction  Churn  \
# 0              39.65              0.00          59.65             3     91
# ...

# %%
# Create a plot with matplotlib
f,ax = plt.subplots(figsize=(12,12))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the plots defined above.
corr = sns.heatmap(sub.corr(), annot = True, ax = ax)

# %% [markdown]
# "Age" & "Avg Monthly GB Download" have a strong relationship. Younger customers download more GB per month
# have a strong relationship.

# %% [markdown]
# "Tenure in Months" & "Total_Charges", "Total_LD_Charges" and "Total_Revenue" have a strong relationship.

# %% [markdown]
# "Tenure in Months" & "CLTV" have a moderate relationship.

# %% [markdown]
# "Avg Monthly Long Distance Charges" & "Total Long Distance Charges" have a strong relationship.

# %% [markdown]
# "Avg Monthly GB Download" & "Monthly_Charge" have a moderate relationship.

# %% [markdown]
# "Monthly Charge" & "Total_Charges" and "Total_Revenue"  have a strong relationship.

# %% [markdown]
# "Total Charge" & "Total_Long Distance_Charges" and "Total_Revenue"  have a strong relationship.

# %% [markdown]
# "Total Charge" &  "CLTV" have a moderate relationship.

# %% [markdown]
# "Total_Revenue" &  "CLTV" have a moderate relationship.

# %% [markdown]
# "Satisfaction" & "CLTV" have a strong relationship.

# %% [markdown]
# ## Scatterplots:

# %%
# Create a scatterplot for the "Age" and "Avg Monthly GB Download" columns in seaborn
sns.lmplot(x = 'Age', y = 'avg_m_GB_download', data = df)

# %% [markdown]
# From the Scatterplots above, we can see that between age 20-30 there is a greater average monthly GB download

# %%
# Create a scatterplot for the "Referrals" and "Tenure_Months" columns in seaborn
sns.lmplot(x = 'Referrals', y = 'Tenure_Months', data = df)

# %%
# Create a scatterplot for the "CLTV" and "Tenure_Months" columns in seaborn
sns.lmplot(x = 'CLTV', y = 'Tenure_Months', data = df)

# %%
# Create a scatterplot for the "CLTV" and "Churn" columns in seaborn
sns.lmplot(x = 'CLTV', y = 'Churn', data = df)

# %% [markdown]
# ## Pair Plots:

# %%
sub_2 = sub[['Age', 'Tenure_Months', 'Satisfaction', 'Churn','CLTV']]

# %%
# Create a pair plot 
g = sns.pairplot(sub_2)
# Out:
# C:\Users\vicky\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\vicky\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\vicky\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ## Categorical Plots

# %%
# Use a histogram to visualize the distribution of the variables. 
sns.histplot(df['Age'], bins = 10, kde = True)
# Out:
# C:\Users\vicky\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df['Tenure_Months'], bins = 12, kde = True)
# Out:
# C:\Users\vicky\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Tenure_Months', ylabel='Count'>

# %%
sns.histplot(df['Churn'], bins = 10, kde = True)
# Out:
# C:\Users\vicky\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Churn', ylabel='Count'>

# %%
df.loc[df['Churn'] < 30, 'Churn Risk'] = 'Low churn risk'

# %%
df.loc[(df['Churn'] >= 30) & (df['Churn'] < 70), 'Churn Risk'] = 'Medium churn risk'

# %%
df.loc[df['Churn'] >= 70, 'Churn Risk'] = 'High churn risk'

# %%
df['Churn Risk'].value_counts(dropna = False)
# Out:
# Churn Risk
# Medium churn risk    3615
# High churn risk      2565
# Low churn risk        863
# Name: count, dtype: int64

# %%
# Create a categorical plot in seaborn using the Churn Risk categories created above

sns.set(style="ticks")
g = sns.catplot(x="Satisfaction", y="Churn", hue="Churn Risk", data=df)
# Out:
# C:\Users\vicky\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\vicky\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# fig = g.get_figure()
g.savefig("out.png")

# %% [markdown]
# This Categorical Plot shows that the customer who has low satisfaction score has a higher churn risk.

# %% [markdown]
# ## Revisit the questions that generated in the previous task

# %% [markdown]
# Q1: Are there any demographic segments (age, gender, location) that are more likely to churn?

# %% [markdown]
# A1: I need to breakdown the age into group and further analysis. For gender and location any recommendation to leverage above plot for exploratory visual analysis?

# %% [markdown]
# Q2: Is there a correlation between satisfaction score and churn rate?

# %% [markdown]
# A2: Yes, based on the above plot the customer who has low satisfaction score has a higher churn risk.

# %% [markdown]
# Q3: How can we use CLTV (Customer Lifetime Value) to identify high-value customers?

# %% [markdown]
# A3: I will need to abalysis further to identify high-value customers

# %% [markdown]
# Q4: Do customers who use multiple services (phone, internet, etc.) churn less?

# %% [markdown]
# A4: I wasn't able to do the analysis through exploratory visual analysis. What's the python syntax I could use to count if customer use multiple services (phone, internet, etc.)

# %% [markdown]
# Q5: What is the impact of internet speed (DSL, Fiber Optic, Cable) on churn?

# %% [markdown]
# A5: I wasn't able to do the analysis through exploratory visual analysis. I will need to investigate further on how to use "String Data Type" on python exploratory visual analysis

# %% [markdown]
# Q6: Do customers who subscribe to additional services (security, backup) have a lower churn rate?

# %% [markdown]
# A6: No answer on this yet. Will require further analysis

# %% [markdown]
# Q7: Do customers on different contract lengths (month-to-month, one-year, two-year) have different churn rates?

# %% [markdown]
# A7: No answer on this yet. Will require further analysis

# %% [markdown]
# Q8: Can we identify key factors that contribute to customer churn using churn score and churn category?

# %% [markdown]
# A8: No answer on this yet. Will require further analysis
